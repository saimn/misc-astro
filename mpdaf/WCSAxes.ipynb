# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline
# %mpdaf
# Out:
# Numpy 1.13.3
# Astropy 2.0.3
# MPDAF 2.5.dev2518

# %%
import matplotlib.pyplot as plt

# %%
im = Image('/home/simon/data/UDF/1.0b1/IMAGE_UDF-10.fits')
im
# Out:
# <Image(shape=(322, 323), unit='1e-20 erg / (Angstrom cm2 s)', dtype='None')>

# %%
#im.plot(zscale=True)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
im[100].plot(ax=ax1, zscale=True, title='row')
im[:, 100].plot(ax=ax2, zscale=True, title='column')

# %%
im.plot(zscale=True, use_wcs=True)
